# %%
import os
import pdfplumber
import pandas as pd
import zipfile
from IPython.display import display, Image
import io

# 定义文件路径
current_dir = os.getcwd()
# 向上两级找到 asset 目录 (如果当前在 notebooks 目录下)
project_root = os.path.abspath(os.path.join(current_dir, '..'))
asset_dir = os.path.join(project_root, 'asset')

pdf_filename = "billionaires_page-1-5.pdf"
epub_filename = "投资第一课 (孟岩) (Z-Library).epub"

pdf_path = os.path.join(asset_dir, pdf_filename)
epub_path = os.path.join(asset_dir, epub_filename)

print(f"PDF Path: {pdf_path}")
print(f"EPUB Path: {epub_path}")

# 检查文件是否存在
if not os.path.exists(pdf_path):
    print("Warning: PDF file not found!")
if not os.path.exists(epub_path):
    print("Warning: EPUB file not found!")
# Out:
# PDF Path: d:\My Data\Rag\rag-project01-framework\asset\billionaires_page-1-5.pdf
# EPUB Path: d:\My Data\Rag\rag-project01-framework\asset\投资第一课 (孟岩) (Z-Library).epub

# %%
if os.path.exists(pdf_path):
    print(f"正在解析: {pdf_filename}...")
    
    with pdfplumber.open(pdf_path) as pdf:
        total_tables = 0
        
        # 遍历每一页
        for i, page in enumerate(pdf.pages):
            # 提取当前页的所有表格
            tables = page.extract_tables()
            
            if tables:
                print(f"\n--- 第 {i+1} 页发现 {len(tables)} 个表格 ---")
                
                for j, table in enumerate(tables):
                    total_tables += 1
                    # 将表格转换为 DataFrame
                    # 假设第一行是表头
                    if len(table) > 1:
                        df = pd.DataFrame(table[1:], columns=table[0])
                    else:
                        df = pd.DataFrame(table)
                    
                    print(f"表格 {j+1} (前5行):")
                    display(df.head())
    
    if total_tables == 0:
        print("在该 PDF 中未检测到表格。")
else:
    print("跳过 PDF 处理：文件不存在")
# Out:
# 正在解析: billionaires_page-1-5.pdf...
#
# --- 第 1 页发现 1 个表格 ---
# 表格 1 (前5行):
#   List of the world's billionaires, ranked in order of net worth
# 0  The net worth of the world's billionaires incr...
# 1                                Publication details
# 2   Publisher Whale Media Investments\nForbes family
# 3                                 Publication Forbes
# 4                      First published March 1987[1]
# --- 第 2 页发现 1 个表格 ---
# 表格 1 (前5行):
#   Icon                                 Description
# 0       Has not changed from the previous ranking.
# 1         Has increased from the previous ranking.
# 2         Has decreased from the previous ranking.
# --- 第 3 页发现 1 个表格 ---
# 表格 1 (前5行):
#   No.                       Name Net worth\n(USD) Age     Nationality  \
# 0   1  Bernard Arnault &\nfamily     $211 billion  74          France
# 1   2                  Elon Musk     $180 billion  51  United\nStates
# 2   3                 Jeff Bezos     $114 billion  59  United\nStates
# 3   4              Larry Ellison     $107 billion  78  United\nStates
# 4   5             Warren Buffett     $106 billion  92  United\nStates
#
#   Primary source(s) of wealth
# 0                        LVMH
# 1      Tesla, SpaceX, X Corp.
# 2                      Amazon
# 3          Oracle Corporation
# 4          Berkshire Hathaway
# --- 第 4 页发现 2 个表格 ---
# 表格 1 (前5行):
#   No.                       Name Net worth\n(USD) Age     Nationality  \
# 0   1                  Elon Musk     $219 billion  50  United\nStates
# 1   2                 Jeff Bezos     $177 billion  58  United\nStates
# 2   3  Bernard Arnault &\nfamily     $158 billion  73          France
# 3   4                 Bill Gates     $129 billion  66  United\nStates
# 4   5             Warren Buffett     $118 billion  91  United\nStates
#
#   Primary source(s) of\nwealth
# 0   Tesla, SpaceX, Twitter Inc
# 1                       Amazon
# 2                         LVMH
# 3                    Microsoft
# 4           Berkshire Hathaway
# 表格 2 (前5行):
#   No.                      Name Net worth (USD) Age    Nationality  \
# 0   1                Jeff Bezos    $177 billion  57  United States
# 1   2                 Elon Musk    $151 billion  49  United States
# 2   3  Bernard Arnault & family    $150 billion  72         France
# 3   4                Bill Gates    $124 billion  65  United States
# 4   5           Mark Zuckerberg     $97 billion  36  United States
#
#   Source(s) of wealth
# 0              Amazon
# 1       Tesla, SpaceX
# 2                LVMH
# 3           Microsoft
# 4      Meta Platforms
# --- 第 5 页发现 2 个表格 ---
# 表格 1 (前5行):
#   No.                      Name Net worth (USD) Age    Nationality  \
# 0   1                Jeff Bezos    $113 billion  56  United States
# 1   2                Bill Gates     $98 billion  64  United States
# 2   3  Bernard Arnault & family     $76 billion  71         France
# 3   4            Warren Buffett   $67.5 billion  89  United States
# 4   5             Larry Ellison     $59 billion  75  United States
#
#   Source(s) of wealth
# 0              Amazon
# 1           Microsoft
# 2                LVMH
# 3  Berkshire Hathaway
# 4  Oracle Corporation
# 表格 2 (前5行):
#   No.             Name Net worth (USD) Age    Nationality  \
# 0   1       Jeff Bezos    $131 billion  55  United States
# 1   2       Bill Gates   $96.5 billion  63  United States
# 2   3   Warren Buffett   $82.5 billion  88  United States
# 3   4  Bernard Arnault     $76 billion  70         France
# 4   5      Carlos Slim     $64 billion  79         Mexico
#
#           Source(s) of wealth
# 0                      Amazon
# 1                   Microsoft
# 2          Berkshire Hathaway
# 3                        LVMH
# 4  América Móvil, Grupo Carso

# %%
if os.path.exists(epub_path):
    print(f"正在解析: {epub_filename}...")
    
    image_count = 0
    
    try:
        with zipfile.ZipFile(epub_path, 'r') as z:
            # 列出所有文件
            all_files = z.namelist()
            
            # 过滤出图片文件 (jpg, png, jpeg, webp)
            image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.webp'))]
            
            print(f"发现 {len(image_files)} 张图片资源。")
            
            # 展示前 5 张图片
            for img_path in image_files[:5]:
                print(f"\n读取图片: {img_path}")
                
                # 读取图片二进制数据
                img_data = z.read(img_path)
                
                # 在 Notebook 中展示
                display(Image(data=img_data, width=300)) # 限制宽度以便展示
                image_count += 1
                
    except zipfile.BadZipFile:
        print("错误：该文件不是有效的 EPUB/ZIP 文件。")
    except Exception as e:
        print(f"处理 EPUB 时出错: {e}")
else:
    print("跳过 EPUB 处理：文件不存在")
# Out:
# 正在解析: 投资第一课 (孟岩) (Z-Library).epub...
# 发现 171 张图片资源。
#
# 读取图片: OEBPS/Images/0000_logo-square-727a22ab924433bf624c1e7aa0b05dae.png
# 读取图片: OEBPS/Images/0001_01ERETD53FSSZRW8TQC7AGRW10.png
# 读取图片: OEBPS/Images/0002_01EC9BB814C3KA6T3BCVD2P0AV.jpg
# 读取图片: OEBPS/Images/0003_badge-employee-3e0ee5bdffa77d712d5cc795c20c2aa4.png
# 读取图片: OEBPS/Images/0004_01EDT6NYMVM7HVFXZ66M5RN4B5.jpg
